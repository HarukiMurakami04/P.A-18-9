# %% [markdown]
# <a href="https://colab.research.google.com/github/HarukiMurakami04/P.A-18-9/blob/main/P_A_18_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos= ["Leticia", "Anderson", "Marcos"]
alunos[1] = "Marcia"
alunos.append("Rafaela")
alunos.remove("Leticia")
print(alunos);
# Out:
# ['Marcia', 'Marcos', 'Rafaela']

# %%
alunos = ("Ana", 17, "informática")

# %%
#Exercicios
#1
frutas=["maçã", "banana", "laranja", "morango"]
print(frutas);
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
#2
nome=["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nome[1]);
print(nome[2]);
# Out:
# Guilherme
# Melissa

# %%
#3
cores=["Vermelho","azul","verde"]
cores[1] = "amarelo"
print(cores[1]);
# Out:
# amarelo

# %%
#4
Alunos=["Nicolas","Wendel","Pyetra"]
Alunos.append("Petros")
print(Alunos);
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
#5
Animais=["Cachorro"," Gato","Coelho", "Passarinho"]
Animais.remove("Coelho")
print(Animais);
# Out:
# ['Cachorro', ' Gato', 'Passarinho']

# %%
#6
meses=("janeiro","fevereiro","março","abril");
print(meses)
# Out:
# ('janeiro', 'fevereiro', 'março', 'abril')

# %%
#7
numero=(10,20,30,40,50);
print(numero[0]);
print(numero[2]);
print(numero[4]);
# Out:
# 10
# 30
# 50

# %%
#8
alunos=("Haruki", "15", "T.I");
print(alunos[0]);
print(alunos[1]);
print(alunos[2]);
# Out:
# Haruki
# 15
# T.I

# %%
#9
cores=["Vermelho","azul","verde"]
cores[1] = "amarelo"
print(cores[1]);
# Out:
# amarelo

# %%
#10
numero=(2,4,6,5,2,7,8,2,10)
numero.count(2);
print(numero.count);
# Out:
# <built-in method count of tuple object at 0x7d623e5e7ed0>
